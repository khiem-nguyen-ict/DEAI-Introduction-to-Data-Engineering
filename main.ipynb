# %%
# Using pandas to load chracters

import pandas as pd
df = pd.read_csv("./star_wars/csv/characters.csv")
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           112 non-null    int64
#  1   name         112 non-null    object
#  2   species      112 non-null    object
#  3   gender       108 non-null    object
#  4   height       83 non-null     float64
#  5   weight       77 non-null     float64
#  6   hair_color   76 non-null     object
#  7   eye_color    104 non-null    object
#  8   skin_color   110 non-null    object
#  9   year_born    80 non-null     object
#  10  homeworld    99 non-null     object
#  11  year_died    50 non-null     object
#  12  description  112 non-null    object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 11.5+ KB
#    id            name         species  gender  height  weight hair_color  \
# 0   1  Luke Skywalker           Human    Male    1.72    77.0      Blond
# ...

# %%
# Find all rows where species is Human

df2 = df.loc[(df['species'] == "Human")]
df2.head()
# Out:
# 1. Is Human
# 1. Is Not Human
#     id           name         species gender  height  weight hair_color  \
# 3    4           Yoda  Yoda's species   Male    0.66    17.0      White
# 5    6      Chewbacca         Wookiee   Male    2.28   112.0      Brown
# 12  13  Jar Jar Binks          Gungan   Male    1.96    66.0        NaN
# 18  19           BB-8           Droid    NaN     NaN     NaN        NaN
# 19  20          C-3PO           Droid    NaN    1.71     NaN        NaN
#
#    eye_color skin_color year_born homeworld year_died  \
# 3      Brown      Green       896   Unknown         4
# 5       Blue      Brown       200  Kashyyyk       NaN
# 12    Orange     Orange        52     Naboo       NaN
# 18       NaN      White       NaN       NaN       NaN
# 19       NaN       Gold       112  Tatooine       NaN
#
#                                           description
# 3                    A wise and powerful Jedi Master.
# 5   A loyal Wookiee and co-pilot of the Millennium...
# ...

# %%
# Find all rows where species is Not Human
df3 = df.loc[(df['species'] != "Human")]
df3.head()
# Out:
#     id           name         species gender  height  weight hair_color  \
# 3    4           Yoda  Yoda's species   Male    0.66    17.0      White
# 5    6      Chewbacca         Wookiee   Male    2.28   112.0      Brown
# 12  13  Jar Jar Binks          Gungan   Male    1.96    66.0        NaN
# 18  19           BB-8           Droid    NaN     NaN     NaN        NaN
# 19  20          C-3PO           Droid    NaN    1.71     NaN        NaN
#
#    eye_color skin_color year_born homeworld year_died  \
# 3      Brown      Green       896   Unknown         4
# 5       Blue      Brown       200  Kashyyyk       NaN
# 12    Orange     Orange        52     Naboo       NaN
# 18       NaN      White       NaN       NaN       NaN
# 19       NaN       Gold       112  Tatooine       NaN
#
#                                           description
# 3                    A wise and powerful Jedi Master.
# 5   A loyal Wookiee and co-pilot of the Millennium...
# ...

# %%
# Find all rows where species is Not Human and Height < 1.5
df4 = df[(df['species'] != "Human") & (df['height'] < 1.5)]
df4.head()
# Out:
#     id               name         species  gender  height  weight hair_color  \
# 3    4               Yoda  Yoda's species    Male    0.66    17.0      White
# 20  21              R2-D2           Droid     NaN    0.96     NaN        NaN
# 27  28         Maz Kanata         Unknown  Female    1.24    31.0        NaN
# 49  50            Sebulba             Dug    Male    1.12    40.0        NaN
# 53  54  Wicket W. Warrick            Ewok    Male    1.00    20.0      Brown
#
#    eye_color  skin_color year_born  homeworld year_died  \
# 3      Brown       Green       896    Unknown         4
# 20       NaN  White/Blue        33      Naboo       NaN
# 27     Brown      Orange       973   Takodana       NaN
# 49       Red       Brown        32  Malastare       NaN
# 53     Brown       Brown        23      Endor       NaN
#
#                                           description
# 3                    A wise and powerful Jedi Master.
# 20  An astromech droid known for his bravery and r...
# ...
